# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '인프런(Inflearn)은 국내 대표적인 온라인 교육 플랫폼 중 하나로, 특히 **IT/개발 분야** 강의가 매우 풍부하고 강세를 보입니다. 하지만 그 외에도 다양한 분야의 강의들을 제공하고 있습니다.\n\n주요 강의 분야와 특징은 다음과 같습니다:\n\n1.  **IT/개발 (가장 핵심 분야)**\n    *   **웹 개발 (프론트엔드/백엔드):** HTML, CSS, JavaScript, React, Vue.js, Angular, Node.js, Spring, Django, Flask, PHP, Go 등\n    *   **모바일 개발:** Android (Kotlin, Java), iOS (Swift, Objective-C)\n    *   **데이터 과학/인공지능:** Python (Pandas, NumPy, Scikit-learn), R, 머신러닝, 딥러닝 (TensorFlow, PyTorch), 데이터 분석, 빅데이터\n    *   **클라우드/인프라/데브옵스:** AWS, Azure, GCP, Docker, Kubernetes, Linux, CI/CD, 네트워크\n    *   **프로그래밍 언어:** C, C++, Java, Python, JavaScript, Go, Rust 등 기초부터 심화까지\n    *   **데이터베이스:** SQL (MySQL, PostgreSQL, Oracle), NoSQL (MongoDB, Redis)\n    *   **알고리즘/자료구조:** 코딩 테스트 대비, 문제 해결 능력 향상\n    *   **게임 개발:** Unity, Unreal Engine\n    *   **정보 보안:** 웹 해킹, 시스템 보안, 네트워크 보안\n    *   **테스트:** TDD, 단위 테스트, 통합 테스트 등\n\n2.  **디자인**\n    *   **UI/UX 디자인:** Figma, Sketch, Adobe XD, 사용자 경험 설계\n    *   **그래픽 디자인:** Photoshop, Illustrator\n    *   **웹/모바일 디자인**\n\n3.  **업무 생산성/직무 역량**\n    *   **데이터 시각화:** Tableau, Power BI\n    *   **스프레드시트:** Excel, Google Sheets\n    *   **기획/마케팅:** 디지털 마케팅, SEO, 콘텐츠 마케팅, 서비스 기획\n    *   **프로젝트 관리:** Jira, Notion, 애자일\n    *   **문서 작성:** PowerPoint, 기획서 작성법\n\n4.  **크리에이티브/취미**\n    *   **영상 편집:** Premiere Pro, After Effects\n    *   **일러스트/드로잉**\n    *   **음악 제작**\n\n5.  **기타**\n    *   **취업/이직:** 면접 준비, 포트폴리오 제작, 이력서 작성\n    *   **강의 제작:** 온라인 강의를 직접 만드는 방법\n\n**인프런 강의의 특징:**\n\n*   **실무 중심:** 많은 강의들이 실제 업무나 프로젝트에 바로 적용할 수 있는 실용적인 내용을 다룹니다.\n*   **다양한 수준:** 초급자를 위한 입문 강의부터 전문가를 위한 심화 강의까지 폭넓게 제공됩니다.\n*   **무료 강의:** 유료 강의 외에도 다양한 주제의 무료 강의들이 있어서 부담 없이 시작해볼 수 있습니다.\n*   **꾸준한 업데이트:** 새로운 기술이나 트렌드에 맞춰 강의가 꾸준히 추가되고 업데이트됩니다.\n*   **질의응답:** 강의별로 강사에게 질문하고 답변을 받을 수 있는 커뮤니티 기능이 잘 되어 있습니다.\n\n특정 분야나 기술에 관심이 있으시다면, 인프런 웹사이트에 접속하셔서 검색창에 키워드를 입력하거나 카테고리를 탐색해보시면 원하는 강의를 쉽게 찾으실 수 있을 겁니다.'
